# %% [markdown]
# # Knowledge Graph Visualization and Hallucination Detection
#
# This notebook visualizes the Hive Fleet Obsidian knowledge graph to help identify potential hallucinations (disconnected or anomalous nodes) and understand the current memory structure.
#
# We will load data from:
# - `memory/semantic/knowledge_graph/evolution_graph.gml`
# - `memory/semantic/knowledge_graph.json` (if available)

# %%
# 1. Install and Import Dependencies
import sys
!{sys.executable} -m pip install networkx matplotlib pandas pyvis scikit-learn

import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import json
import os
from pathlib import Path
from pyvis.network import Network
import numpy as np

# Set paths
WORKSPACE_ROOT = Path("..") # Assuming notebook is in notebooks/
GML_PATH = WORKSPACE_ROOT / "memory/semantic/knowledge_graph/evolution_graph.gml"
JSON_PATH = WORKSPACE_ROOT / "memory/semantic/knowledge_graph.json"

print(f"Checking paths:\n{GML_PATH}: {GML_PATH.exists()}\n{JSON_PATH}: {JSON_PATH.exists()}")
# Out:
# ERROR:no viable alternative at input '1' (1.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'and' (1.sysml line : 1 column : 14)
# ERROR:no viable alternative at input 'Dependencies' (1.sysml line : 1 column : 25)
# ERROR:no viable alternative at input 'import' (1.sysml line : 2 column : 1)
# ERROR:no viable alternative at character '{' (1.sysml line : 3 column : 1)
# ERROR:no viable alternative at input '.' (1.sysml line : 3 column : 6)
# ERROR:no viable alternative at input '}' (1.sysml line : 3 column : 17)
# ERROR:missing EOF at '-' (1.sysml line : 3 column : 19)

# %%
# 2. Load Knowledge Graph Data

G = None

# Try loading GML first as it seems to be the primary evolution graph
if GML_PATH.exists():
    try:
        print(f"Loading GML from {GML_PATH}...")
        G = nx.read_gml(GML_PATH)
        print(f"Successfully loaded GML. Nodes: {len(G.nodes)}, Edges: {len(G.edges)}")
    except Exception as e:
        print(f"Error loading GML: {e}")

# If GML failed or we want to merge/compare, try JSON
if JSON_PATH.exists():
    try:
        print(f"Loading JSON from {JSON_PATH}...")
        with open(JSON_PATH, 'r') as f:
            data = json.load(f)
        
        G_json = nx.node_link_graph(data)
        print(f"Successfully loaded JSON. Nodes: {len(G_json.nodes)}, Edges: {len(G_json.edges)}")
        
        if G is None:
            G = G_json
        else:
            print("Both graphs found. Using GML as primary for now.")
            # You could merge them here if needed: G = nx.compose(G, G_json)
            
    except Exception as e:
        print(f"Error loading JSON: {e}")

if G is None:
    print("No graph data found. Creating a sample graph for demonstration.")
    G = nx.gnm_random_graph(20, 30, directed=True)
    for i in G.nodes:
        G.nodes[i]['label'] = f"Node_{i}"
# Out:
# ERROR:no viable alternative at input '2' (2.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'Knowledge' (2.sysml line : 1 column : 11)
# ERROR:no viable alternative at input 'Graph' (2.sysml line : 1 column : 21)
# ERROR:no viable alternative at input 'Data' (2.sysml line : 1 column : 27)
# ERROR:no viable alternative at input 'G' (2.sysml line : 3 column : 1)
# ERROR:missing '(' at 'Try' (2.sysml line : 5 column : 3)
# ERROR:no viable alternative at input 'GML' (2.sysml line : 5 column : 15)
# ERROR:no viable alternative at input 'first' (2.sysml line : 5 column : 19)
# ERROR:no viable alternative at input 'seems' (2.sysml line : 5 column : 31)
# ERROR:no viable alternative at input 'to' (2.sysml line : 5 column : 37)
# ERROR:no viable alternative at input 'the' (2.sysml line : 5 column : 43)
# ERROR:no viable alternative at input 'primary' (2.sysml line : 5 column : 47)
# ERROR:no viable alternative at input 'evolution' (2.sysml line : 5 column : 55)
# ERROR:no viable alternative at input 'graph' (2.sysml line : 5 column : 65)
# ERROR:no viable alternative at input 'if' (2.sysml line : 6 column : 1)
# ERROR:no viable alternative at input '.' (2.sysml line : 6 column : 12)
# ERROR:no viable alternative at input '(' (2.sysml line : 6 column : 19)
# ERROR:no viable alternative at input '(' (2.sysml line : 8 column : 9)
# ERROR:no viable alternative at input 'f' (2.sysml line : 8 column : 15)
# ERROR:no viable alternative at input '"Loading GML from {GML_PATH}..."' (2.sysml line : 8 column : 16)
# ERROR:no viable alternative at input 'print' (2.sysml line : 10 column : 9)
# ERROR:no viable alternative at input '(' (2.sysml line : 10 column : 14)
# ERROR:no viable alternative at input '"Successfully loaded GML. Nodes: {len(G.nodes)}, Edges: {len(G.edges)}"' (2.sysml line : 10 column : 16)
# ERROR:no viable alternative at input 'Exception' (2.sysml line : 11 column : 12)
# ERROR:no viable alternative at input 'as' (2.sysml line : 11 column : 22)
# ERROR:no viable alternative at input '(' (2.sysml line : 12 column : 9)
# ERROR:no viable alternative at input 'f' (2.sysml line : 12 column : 15)
# ERROR:no viable alternative at input '"Error loading GML: {e}"' (2.sysml line : 12 column : 16)
# ERROR:no viable alternative at input 'failed' (2.sysml line : 14 column : 10)
# ERROR:no viable alternative at input 'or' (2.sysml line : 14 column : 17)
# ERROR:no viable alternative at input 'want' (2.sysml line : 14 column : 23)
# ERROR:no viable alternative at input 'to' (2.sysml line : 14 column : 28)
# ERROR:no viable alternative at input ',' (2.sysml line : 14 column : 44)
# ERROR:no viable alternative at input 'JSON' (2.sysml line : 14 column : 50)
# ERROR:no viable alternative at input 'if' (2.sysml line : 15 column : 1)
# ERROR:no viable alternative at input '.' (2.sysml line : 15 column : 13)
# ERROR:no viable alternative at input '(' (2.sysml line : 15 column : 20)
# ERROR:no viable alternative at input '(' (2.sysml line : 17 column : 9)
# ERROR:no viable alternative at input 'f' (2.sysml line : 17 column : 15)
# ERROR:no viable alternative at input '"Loading JSON from {JSON_PATH}..."' (2.sysml line : 17 column : 16)
# ERROR:no viable alternative at input 'open' (2.sysml line : 18 column : 14)
# ERROR:no viable alternative at input '(' (2.sysml line : 18 column : 18)
# ERROR:no viable alternative at input ',' (2.sysml line : 18 column : 28)
# ERROR:no viable alternative at input ')' (2.sysml line : 18 column : 33)
# ERROR:no viable alternative at input 'G_json' (2.sysml line : 21 column : 9)
# ERROR:no viable alternative at input 'print' (2.sysml line : 22 column : 9)
# ERROR:no viable alternative at input '(' (2.sysml line : 22 column : 14)
# ERROR:no viable alternative at input '"Successfully loaded JSON. Nodes: {len(G_json.nodes)}, Edges: {len(G_json.edges)}"' (2.sysml line : 22 column : 16)
# ERROR:no viable alternative at input 'is' (2.sysml line : 24 column : 14)
# ERROR:no viable alternative at input 'None' (2.sysml line : 24 column : 17)
# ERROR:no viable alternative at input 'else' (2.sysml line : 26 column : 9)
# ERROR:no viable alternative at input '(' (2.sysml line : 27 column : 13)
# ERROR:no viable alternative at input '#' (2.sysml line : 28 column : 13)
# ERROR:no viable alternative at input 'merge' (2.sysml line : 28 column : 25)
# ERROR:no viable alternative at input 'here' (2.sysml line : 28 column : 36)
# ERROR:no viable alternative at input 'if' (2.sysml line : 28 column : 41)
# ERROR:no viable alternative at input 'except' (2.sysml line : 30 column : 5)
# ERROR:no viable alternative at input 'Exception' (2.sysml line : 30 column : 12)
# ERROR:no viable alternative at input 'as' (2.sysml line : 30 column : 22)
# ERROR:no viable alternative at input '(' (2.sysml line : 31 column : 9)
# ERROR:no viable alternative at input 'f' (2.sysml line : 31 column : 15)
# ERROR:no viable alternative at input '"Error loading JSON: {e}"' (2.sysml line : 31 column : 16)
# ERROR:no viable alternative at input 'is' (2.sysml line : 33 column : 6)
# ERROR:no viable alternative at input 'None' (2.sysml line : 33 column : 9)
# ERROR:no viable alternative at input '(' (2.sysml line : 34 column : 5)
# ERROR:no viable alternative at input 'G' (2.sysml line : 35 column : 5)
# ERROR:no viable alternative at input '=' (2.sysml line : 35 column : 37)
# ERROR:no viable alternative at input ')' (2.sysml line : 35 column : 50)
# ERROR:no viable alternative at input 'in' (2.sysml line : 36 column : 11)
# ERROR:no viable alternative at input '.' (2.sysml line : 36 column : 15)
# ERROR:no viable alternative at input '[' (2.sysml line : 37 column : 16)
# ERROR:no viable alternative at input ']' (2.sysml line : 37 column : 18)
# ERROR:no viable alternative at input '"Node_{i}"' (2.sysml line : 37 column : 31)

# %%
# 3. Visualize the Knowledge Graph (Static)

plt.figure(figsize=(15, 10))
pos = nx.spring_layout(G, k=0.15, iterations=20)

# Draw nodes
nx.draw_networkx_nodes(G, pos, node_size=50, node_color="skyblue", alpha=0.7)

# Draw edges
nx.draw_networkx_edges(G, pos, width=0.5, alpha=0.5, edge_color="gray")

# Draw labels (only for high degree nodes to avoid clutter)
degrees = dict(G.degree())
top_nodes = sorted(degrees, key=degrees.get, reverse=True)[:20]
labels = {n: G.nodes[n].get('label', n) for n in top_nodes}
nx.draw_networkx_labels(G, pos, labels, font_size=8)

plt.title("Knowledge Graph Visualization (Static)")
plt.axis("off")
plt.show()
# Out:
# ERROR:no viable alternative at input '3' (3.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'the' (3.sysml line : 1 column : 16)
# ERROR:no viable alternative at input 'Knowledge' (3.sysml line : 1 column : 20)
# ERROR:no viable alternative at input 'Graph' (3.sysml line : 1 column : 30)
# ERROR:no viable alternative at input '(' (3.sysml line : 1 column : 36)
# ERROR:no viable alternative at input ')' (3.sysml line : 1 column : 43)
# ERROR:no viable alternative at input '.' (3.sysml line : 3 column : 4)
# ERROR:no viable alternative at input '(' (3.sysml line : 3 column : 11)
# ERROR:no viable alternative at input ')' (3.sysml line : 3 column : 28)
# ERROR:no viable alternative at input '=' (3.sysml line : 4 column : 27)
# ERROR:no viable alternative at input ')' (3.sysml line : 4 column : 48)
# ERROR:no viable alternative at input 'nx' (3.sysml line : 7 column : 1)
# ERROR:no viable alternative at input '.' (3.sysml line : 7 column : 3)
# ERROR:no viable alternative at input '(' (3.sysml line : 7 column : 23)
# ERROR:no viable alternative at input ',' (3.sysml line : 7 column : 25)
# ERROR:no viable alternative at input ',' (3.sysml line : 7 column : 30)
# ERROR:no viable alternative at input ',' (3.sysml line : 7 column : 44)
# ERROR:no viable alternative at input ',' (3.sysml line : 7 column : 66)
# ERROR:no viable alternative at input ')' (3.sysml line : 7 column : 77)
# ERROR:no viable alternative at input 'nx' (3.sysml line : 10 column : 1)
# ERROR:no viable alternative at input '.' (3.sysml line : 10 column : 3)
# ERROR:no viable alternative at input '(' (3.sysml line : 10 column : 23)
# ERROR:no viable alternative at input ',' (3.sysml line : 10 column : 25)
# ERROR:no viable alternative at input ',' (3.sysml line : 10 column : 30)
# ERROR:no viable alternative at input ',' (3.sysml line : 10 column : 41)
# ERROR:no viable alternative at input ',' (3.sysml line : 10 column : 52)
# ERROR:no viable alternative at input ')' (3.sysml line : 10 column : 71)
# ERROR:no viable alternative at input '(' (3.sysml line : 12 column : 15)
# ERROR:no viable alternative at input 'for' (3.sysml line : 12 column : 21)
# ERROR:no viable alternative at input 'degree' (3.sysml line : 12 column : 30)
# ERROR:no viable alternative at input 'nodes' (3.sysml line : 12 column : 37)
# ERROR:no viable alternative at input 'to' (3.sysml line : 12 column : 43)
# ERROR:no viable alternative at input 'clutter' (3.sysml line : 12 column : 52)
# ERROR:no viable alternative at input ')' (3.sysml line : 12 column : 59)
# ERROR:no viable alternative at input 'top_nodes' (3.sysml line : 14 column : 1)
# ERROR:no viable alternative at input '=' (3.sysml line : 14 column : 29)
# ERROR:no viable alternative at input '.' (3.sysml line : 14 column : 40)
# ERROR:no viable alternative at input ',' (3.sysml line : 14 column : 44)
# ERROR:no viable alternative at input ')' (3.sysml line : 14 column : 58)
# ERROR:no viable alternative at input ':' (3.sysml line : 14 column : 59)
# ERROR:no viable alternative at input '20' (3.sysml line : 14 column : 60)
# ERROR:no viable alternative at input 'labels' (3.sysml line : 15 column : 1)
# ERROR:no viable alternative at input ':' (3.sysml line : 15 column : 11)
# ERROR:no viable alternative at input '.' (3.sysml line : 15 column : 21)
# ERROR:no viable alternative at input ']' (3.sysml line : 15 column : 23)
# ERROR:no viable alternative at input '(' (3.sysml line : 15 column : 28)
# ERROR:no viable alternative at input ',' (3.sysml line : 15 column : 36)
# ERROR:no viable alternative at input ')' (3.sysml line : 15 column : 39)
# ERROR:no viable alternative at input 'in' (3.sysml line : 15 column : 47)
# ERROR:no viable alternative at input '}' (3.sysml line : 15 column : 59)
# ERROR:no viable alternative at input '.' (3.sysml line : 16 column : 3)
# ERROR:no viable alternative at input '(' (3.sysml line : 16 column : 24)
# ERROR:no viable alternative at input ',' (3.sysml line : 16 column : 26)
# ERROR:no viable alternative at input ',' (3.sysml line : 16 column : 31)
# ERROR:no viable alternative at input ',' (3.sysml line : 16 column : 39)
# ERROR:no viable alternative at input ')' (3.sysml line : 16 column : 52)
# ERROR:no viable alternative at input '.' (3.sysml line : 18 column : 4)
# ERROR:no viable alternative at input '(' (3.sysml line : 18 column : 10)
# ERROR:no viable alternative at input '.' (3.sysml line : 19 column : 4)
# ERROR:no viable alternative at input '(' (3.sysml line : 19 column : 9)
# ERROR:no viable alternative at input '.' (3.sysml line : 20 column : 4)
# ERROR:no viable alternative at input '(' (3.sysml line : 20 column : 9)

# %%
# 4. Analyze Graph Statistics & Centrality

print(f"Number of nodes: {G.number_of_nodes()}")
print(f"Number of edges: {G.number_of_edges()}")
print(f"Density: {nx.density(G):.4f}")

if nx.is_directed(G):
    print(f"Is strongly connected: {nx.is_strongly_connected(G)}")
    print(f"Number of strongly connected components: {nx.number_strongly_connected_components(G)}")
    print(f"Number of weakly connected components: {nx.number_weakly_connected_components(G)}")
else:
    print(f"Is connected: {nx.is_connected(G)}")
    print(f"Number of connected components: {nx.number_connected_components(G)}")

# Centrality
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G)

# Top 10 central nodes
print("\nTop 10 Nodes by Degree Centrality:")
for node in sorted(degree_centrality, key=degree_centrality.get, reverse=True)[:10]:
    print(f"{node} ({G.nodes[node].get('label', node)}): {degree_centrality[node]:.4f}")
# Out:
# ERROR:no viable alternative at input '4' (4.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'Graph' (4.sysml line : 1 column : 14)
# ERROR:no viable alternative at input 'Statistics' (4.sysml line : 1 column : 20)
# ERROR:no viable alternative at input '&' (4.sysml line : 1 column : 31)
# ERROR:no viable alternative at input 'print' (4.sysml line : 3 column : 1)
# ERROR:no viable alternative at input '(' (4.sysml line : 3 column : 6)
# ERROR:no viable alternative at input '"Number of nodes: {G.number_of_nodes()}"' (4.sysml line : 3 column : 8)
# ERROR:no viable alternative at input '(' (4.sysml line : 4 column : 6)
# ERROR:no viable alternative at input '"Number of edges: {G.number_of_edges()}"' (4.sysml line : 4 column : 8)
# ERROR:no viable alternative at input '(' (4.sysml line : 5 column : 6)
# ERROR:no viable alternative at input '"Density: {nx.density(G):.4f}"' (4.sysml line : 5 column : 8)
# ERROR:no viable alternative at input '.' (4.sysml line : 7 column : 6)
# ERROR:no viable alternative at input '(' (4.sysml line : 7 column : 18)
# ERROR:no viable alternative at input ')' (4.sysml line : 7 column : 20)
# ERROR:no viable alternative at input '(' (4.sysml line : 8 column : 5)
# ERROR:no viable alternative at input 'f' (4.sysml line : 8 column : 11)
# ERROR:no viable alternative at input '"Is strongly connected: {nx.is_strongly_connected(G)}"' (4.sysml line : 8 column : 12)
# ERROR:no viable alternative at input '(' (4.sysml line : 9 column : 10)
# ERROR:no viable alternative at input '"Number of strongly connected components: {nx.number_strongly_connected_components(G)}"' (4.sysml line : 9 column : 12)
# ERROR:no viable alternative at input '(' (4.sysml line : 10 column : 10)
# ERROR:no viable alternative at input '"Number of weakly connected components: {nx.number_weakly_connected_components(G)}"' (4.sysml line : 10 column : 12)
# ERROR:no viable alternative at input '(' (4.sysml line : 12 column : 5)
# ERROR:no viable alternative at input 'f' (4.sysml line : 12 column : 11)
# ERROR:no viable alternative at input '"Is connected: {nx.is_connected(G)}"' (4.sysml line : 12 column : 12)
# ERROR:no viable alternative at input '(' (4.sysml line : 13 column : 10)
# ERROR:no viable alternative at input '"Number of connected components: {nx.number_connected_components(G)}"' (4.sysml line : 13 column : 12)
# ERROR:no viable alternative at input 'betweenness_centrality' (4.sysml line : 17 column : 1)
# ERROR:missing '(' at 'Top' (4.sysml line : 19 column : 3)
# ERROR:no viable alternative at input 'nodes' (4.sysml line : 19 column : 18)
# ERROR:no viable alternative at input 'print' (4.sysml line : 20 column : 1)
# ERROR:no viable alternative at input '(' (4.sysml line : 20 column : 6)
# ERROR:no viable alternative at input 'in' (4.sysml line : 21 column : 10)
# ERROR:no viable alternative at input '(' (4.sysml line : 21 column : 19)
# ERROR:no viable alternative at input ',' (4.sysml line : 21 column : 37)
# ERROR:no viable alternative at input ',' (4.sysml line : 21 column : 64)
# ERROR:no viable alternative at input ')' (4.sysml line : 21 column : 78)
# ERROR:no viable alternative at input ':' (4.sysml line : 21 column : 79)
# ERROR:no viable alternative at input '10' (4.sysml line : 21 column : 80)
# ERROR:no viable alternative at input ':' (4.sysml line : 21 column : 84)
# ERROR:no viable alternative at input '(' (4.sysml line : 22 column : 5)
# ERROR:no viable alternative at input 'f' (4.sysml line : 22 column : 11)
# ERROR:no viable alternative at input '"{node} ({G.nodes[node].get('label', node)}): {degree_centrality[node]:.4f}"' (4.sysml line : 22 column : 12)

# %%
# 5. Detect Disconnected Subgraphs (Potential Hallucinations)

# Identify weakly connected components (for directed graphs) or connected components
if nx.is_directed(G):
    components = list(nx.weakly_connected_components(G))
else:
    components = list(nx.connected_components(G))

print(f"Found {len(components)} disconnected components.")

# Sort components by size
components.sort(key=len, reverse=True)

# The largest component is likely the "Main" knowledge base
main_component = components[0]
print(f"Main component size: {len(main_component)}")

# Smaller components might be hallucinations or isolated knowledge islands
hallucination_candidates = components[1:]
print(f"Potential hallucination islands: {len(hallucination_candidates)}")

for i, comp in enumerate(hallucination_candidates[:10]):
    print(f"  Island {i+1} (Size {len(comp)}): {[G.nodes[n].get('label', n) for n in list(comp)[:5]]}...")

# Visualize these islands
if hallucination_candidates:
    # Create a subgraph of just the islands (limit to top 50 islands to avoid crashing)
    island_nodes = set()
    for comp in hallucination_candidates[:50]:
        island_nodes.update(comp)
    
    H = G.subgraph(island_nodes)
    
    plt.figure(figsize=(12, 8))
    pos_h = nx.spring_layout(H)
    nx.draw(H, pos_h, with_labels=True, node_size=100, font_size=8, node_color="salmon")
    plt.title("Visualization of Disconnected 'Islands' (Potential Hallucinations)")
    plt.show()
else:
    print("No disconnected islands found.")
# Out:
# ERROR:no viable alternative at input '5' (5.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'Disconnected' (5.sysml line : 1 column : 13)
# ERROR:no viable alternative at input 'Subgraphs' (5.sysml line : 1 column : 26)
# ERROR:no viable alternative at input '(' (5.sysml line : 1 column : 36)
# ERROR:no viable alternative at input 'Hallucinations' (5.sysml line : 1 column : 47)
# ERROR:no viable alternative at input ')' (5.sysml line : 1 column : 61)
# ERROR:no viable alternative at input 'connected' (5.sysml line : 3 column : 19)
# ERROR:no viable alternative at input 'components' (5.sysml line : 3 column : 29)
# ERROR:no viable alternative at input '(' (5.sysml line : 3 column : 40)
# ERROR:no viable alternative at input 'graphs' (5.sysml line : 3 column : 54)
# ERROR:no viable alternative at input ')' (5.sysml line : 3 column : 60)
# ERROR:no viable alternative at input 'components' (5.sysml line : 3 column : 75)
# ERROR:no viable alternative at input 'if' (5.sysml line : 4 column : 1)
# ERROR:no viable alternative at input '.' (5.sysml line : 4 column : 6)
# ERROR:no viable alternative at input '(' (5.sysml line : 4 column : 18)
# ERROR:no viable alternative at input ')' (5.sysml line : 4 column : 20)
# ERROR:no viable alternative at input 'else' (5.sysml line : 6 column : 1)
# ERROR:no viable alternative at input 'print' (5.sysml line : 9 column : 1)
# ERROR:no viable alternative at input '(' (5.sysml line : 9 column : 6)
# ERROR:no viable alternative at input '"Found {len(components)} disconnected components."' (5.sysml line : 9 column : 8)
# ERROR:no viable alternative at input 'by' (5.sysml line : 11 column : 19)
# ERROR:no viable alternative at input 'components' (5.sysml line : 12 column : 1)
# ERROR:no viable alternative at input '.' (5.sysml line : 12 column : 11)
# ERROR:no viable alternative at input '(' (5.sysml line : 12 column : 16)
# ERROR:no viable alternative at input ',' (5.sysml line : 12 column : 24)
# ERROR:no viable alternative at input ')' (5.sysml line : 12 column : 38)
# ERROR:no viable alternative at input 'component' (5.sysml line : 14 column : 15)
# ERROR:no viable alternative at input 'is' (5.sysml line : 14 column : 25)
# ERROR:no viable alternative at input 'likely' (5.sysml line : 14 column : 28)
# ERROR:no viable alternative at input 'the' (5.sysml line : 14 column : 35)
# ERROR:no viable alternative at input '"Main"' (5.sysml line : 14 column : 39)
# ERROR:no viable alternative at input 'base' (5.sysml line : 14 column : 56)
# ERROR:no viable alternative at input 'main_component' (5.sysml line : 15 column : 1)
# ERROR:no viable alternative at input 'print' (5.sysml line : 16 column : 1)
# ERROR:no viable alternative at input '(' (5.sysml line : 16 column : 6)
# ERROR:no viable alternative at input '"Main component size: {len(main_component)}"' (5.sysml line : 16 column : 8)
# ERROR:no viable alternative at input 'might' (5.sysml line : 18 column : 22)
# ERROR:no viable alternative at input 'be' (5.sysml line : 18 column : 28)
# ERROR:no viable alternative at input 'hallucinations' (5.sysml line : 18 column : 31)
# ERROR:no viable alternative at input 'or' (5.sysml line : 18 column : 46)
# ERROR:no viable alternative at input 'knowledge' (5.sysml line : 18 column : 58)
# ERROR:no viable alternative at input 'islands' (5.sysml line : 18 column : 68)
# ERROR:no viable alternative at input 'hallucination_candidates' (5.sysml line : 19 column : 1)
# ERROR:no viable alternative at input '1' (5.sysml line : 19 column : 39)
# ERROR:extraneous input ':' expecting ']' (5.sysml line : 19 column : 40)
# ERROR:no viable alternative at input 'print' (5.sysml line : 20 column : 1)
# ERROR:no viable alternative at input '(' (5.sysml line : 20 column : 6)
# ERROR:no viable alternative at input '"Potential hallucination islands: {len(hallucination_candidates)}"' (5.sysml line : 20 column : 8)
# ERROR:no viable alternative at input ',' (5.sysml line : 22 column : 6)
# ERROR:no viable alternative at input 'in' (5.sysml line : 22 column : 13)
# ERROR:no viable alternative at input '(' (5.sysml line : 22 column : 25)
# ERROR:no viable alternative at input ':' (5.sysml line : 22 column : 50)
# ERROR:no viable alternative at input '10' (5.sysml line : 22 column : 51)
# ERROR:no viable alternative at input ':' (5.sysml line : 22 column : 56)
# ERROR:no viable alternative at input '(' (5.sysml line : 23 column : 5)
# ERROR:no viable alternative at input 'f' (5.sysml line : 23 column : 11)
# ERROR:no viable alternative at input '"  Island {i+1} (Size {len(comp)}): {[G.nodes[n].get('label', n) for n in list(comp)[:5]]}..."' (5.sysml line : 23 column : 12)
# ERROR:no viable alternative at input 'islands' (5.sysml line : 25 column : 19)
# ERROR:no viable alternative at input 'if' (5.sysml line : 26 column : 1)
# ERROR:no viable alternative at input '#' (5.sysml line : 26 column : 28)
# ERROR:no viable alternative at input 'subgraph' (5.sysml line : 27 column : 16)
# ERROR:no viable alternative at input 'of' (5.sysml line : 27 column : 25)
# ERROR:no viable alternative at input 'the' (5.sysml line : 27 column : 33)
# ERROR:no viable alternative at input 'islands' (5.sysml line : 27 column : 37)
# ERROR:no viable alternative at input '(' (5.sysml line : 27 column : 45)
# ERROR:no viable alternative at input 'to' (5.sysml line : 27 column : 52)
# ERROR:no viable alternative at input '50' (5.sysml line : 27 column : 59)
# ERROR:no viable alternative at input 'to' (5.sysml line : 27 column : 70)
# ERROR:no viable alternative at input 'crashing' (5.sysml line : 27 column : 79)
# ERROR:no viable alternative at input ')' (5.sysml line : 27 column : 87)
# ERROR:no viable alternative at input 'for' (5.sysml line : 29 column : 5)
# ERROR:no viable alternative at input 'in' (5.sysml line : 29 column : 14)
# ERROR:no viable alternative at input ':' (5.sysml line : 29 column : 41)
# ERROR:no viable alternative at input '50' (5.sysml line : 29 column : 42)
# ERROR:no viable alternative at input ':' (5.sysml line : 29 column : 46)
# ERROR:no viable alternative at input '(' (5.sysml line : 30 column : 28)
# ERROR:no viable alternative at input 'comp' (5.sysml line : 30 column : 29)
# ERROR:no viable alternative at input ')' (5.sysml line : 30 column : 33)
# ERROR:no viable alternative at input 'plt' (5.sysml line : 34 column : 5)
# ERROR:no viable alternative at input '.' (5.sysml line : 34 column : 8)
# ERROR:no viable alternative at input '(' (5.sysml line : 34 column : 15)
# ERROR:no viable alternative at input ')' (5.sysml line : 34 column : 31)
# ERROR:no viable alternative at input 'nx' (5.sysml line : 36 column : 5)
# ERROR:no viable alternative at input '.' (5.sysml line : 36 column : 7)
# ERROR:no viable alternative at input '(' (5.sysml line : 36 column : 12)
# ERROR:no viable alternative at input ',' (5.sysml line : 36 column : 14)
# ERROR:no viable alternative at input ',' (5.sysml line : 36 column : 21)
# ERROR:no viable alternative at input ',' (5.sysml line : 36 column : 39)
# ERROR:no viable alternative at input ',' (5.sysml line : 36 column : 54)
# ERROR:no viable alternative at input ',' (5.sysml line : 36 column : 67)
# ERROR:no viable alternative at input ')' (5.sysml line : 36 column : 88)
# ERROR:no viable alternative at input '.' (5.sysml line : 37 column : 8)
# ERROR:no viable alternative at input '(' (5.sysml line : 37 column : 14)
# ERROR:no viable alternative at input '.' (5.sysml line : 38 column : 8)
# ERROR:no viable alternative at input '(' (5.sysml line : 38 column : 13)
# ERROR:no viable alternative at input '(' (5.sysml line : 40 column : 5)
# ERROR:no viable alternative at input '<EOF>' (5.sysml line : 40 column : 43)

# %%
# 6. Interactive Visualization with PyVis

# Create a PyVis network
net = Network(notebook=True, height="750px", width="100%", bgcolor="#222222", font_color="white")

# For large graphs, we might want to sample or filter
# Let's visualize the main component + top 5 islands to keep it performant
nodes_to_viz = set(list(main_component)[:500]) # Limit main component nodes
for comp in hallucination_candidates[:10]:
    nodes_to_viz.update(comp)

subgraph = G.subgraph(nodes_to_viz)

net.from_nx(subgraph)

# Add some physics options
net.toggle_physics(True)
net.show_buttons(filter_=['physics'])

# Save and display
output_path = "knowledge_graph_interactive.html"
net.show(output_path)
print(f"Interactive graph saved to {output_path}. Open this file in a browser to explore.")
# Out:
# ERROR:no viable alternative at input '6' (6.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'Visualization' (6.sysml line : 1 column : 18)
# ERROR:no viable alternative at input 'with' (6.sysml line : 1 column : 32)
# ERROR:no viable alternative at input 'PyVis' (6.sysml line : 1 column : 37)
# ERROR:no viable alternative at input '#' (6.sysml line : 3 column : 1)
# ERROR:no viable alternative at input 'PyVis' (6.sysml line : 3 column : 12)
# ERROR:no viable alternative at input 'network' (6.sysml line : 3 column : 18)
# ERROR:no viable alternative at input 'net' (6.sysml line : 4 column : 1)
# ERROR:missing '(' at 'For' (6.sysml line : 6 column : 3)
# ERROR:no viable alternative at input 'graphs' (6.sysml line : 6 column : 13)
# ERROR:no viable alternative at input ',' (6.sysml line : 6 column : 19)
# ERROR:no viable alternative at input 'might' (6.sysml line : 6 column : 24)
# ERROR:no viable alternative at input 'want' (6.sysml line : 6 column : 30)
# ERROR:no viable alternative at input 'to' (6.sysml line : 6 column : 35)
# ERROR:no viable alternative at input 'or' (6.sysml line : 6 column : 45)
# ERROR:no viable alternative at input '#' (6.sysml line : 7 column : 1)
# ERROR:no viable alternative at input 'physics' (6.sysml line : 18 column : 28)
# ERROR:mismatched character '<EOF>' expecting ''' (6.sysml line : 18 column : 35)

# %%
# 7. Export to Mermaid (Swarmlord's View)
# Since the full graph is too large for Mermaid, we will export the "Core" (Top 30 Central Nodes)
# and their direct connections. This provides a high-level strategic view.

def export_to_mermaid(graph, output_file="core_memory.mmd", limit=30):
    # Calculate centrality to find the "Core"
    centrality = nx.degree_centrality(graph)
    top_nodes = sorted(centrality, key=centrality.get, reverse=True)[:limit]
    
    subgraph = graph.subgraph(top_nodes)
    
    mermaid_lines = ["graph TD"]
    
    # Add nodes and edges
    # Sanitize IDs for Mermaid (remove spaces, special chars)
    def sanitize(text):
        return str(text).replace(" ", "_").replace(".", "_").replace("/", "_").replace("-", "_")

    for u, v in subgraph.edges():
        u_safe = sanitize(u)
        v_safe = sanitize(v)
        # Try to get labels if they exist, else use ID
        u_label = graph.nodes[u].get('label', u)
        v_label = graph.nodes[v].get('label', v)
        
        # Escape quotes in labels
        u_label = str(u_label).replace('"', "'")
        v_label = str(v_label).replace('"', "'")
        
        line = f'    {u_safe}["{u_label}"] --> {v_safe}["{v_label}"]'
        mermaid_lines.append(line)
        
    content = "\n".join(mermaid_lines)
    
    with open(output_file, "w") as f:
        f.write(content)
    
    print(f"Mermaid diagram exported to {output_file}")
    print("Copy the content of this file into a Markdown block or Mermaid Live Editor.")
    return content

# Export the core graph
mermaid_code = export_to_mermaid(G, "core_memory.mmd")
print("\n--- Preview (First 10 lines) ---")
print("\n".join(mermaid_code.split("\n")[:10]))
# Out:
# ERROR:no viable alternative at input '7' (7.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'to' (7.sysml line : 1 column : 13)
# ERROR:no viable alternative at input '(' (7.sysml line : 1 column : 24)
# ERROR:no viable alternative at input ''s View)\n# Since the full graph is too large for Mermaid, we will export the "Core" (Top 30 Central Nodes)\n# and their direct connections. This provides a high-level strategic view.\n\ndef export_to_mermaid(graph, output_file="core_memory.mmd", limit=30):\n    # Calculate centrality to find the "Core"\n    centrality = nx.degree_centrality(graph)\n    top_nodes = sorted(centrality, key=centrality.get, reverse=True)[:limit]\n    \n    subgraph = graph.subgraph(top_nodes)\n    \n    mermaid_lines = ["graph TD"]\n    \n    # Add nodes and edges\n    # Sanitize IDs for Mermaid (remove spaces, special chars)\n    def sanitize(text):\n        return str(text).replace(" ", "_").replace(".", "_").replace("/", "_").replace("-", "_")\n\n    for u, v in subgraph.edges():\n        u_safe = sanitize(u)\n        v_safe = sanitize(v)\n        # Try to get labels if they exist, else use ID\n        u_label = graph.nodes[u].get('' (7.sysml line : 1 column : 34)
# ERROR:no viable alternative at input 'label' (7.sysml line : 23 column : 39)
# ERROR:no viable alternative at input '', u)\n        v_label = graph.nodes[v].get('' (7.sysml line : 23 column : 44)
# ERROR:no viable alternative at input 'label' (7.sysml line : 24 column : 39)
# ERROR:no viable alternative at input '', v)\n        \n        # Escape quotes in labels\n        u_label = str(u_label).replace('' (7.sysml line : 24 column : 44)
# ERROR:no viable alternative at input '"', "' (7.sysml line : 27 column : 41)
# ERROR:no viable alternative at input '"', "' (7.sysml line : 28 column : 41)
# ERROR:no viable alternative at input '}' (7.sysml line : 30 column : 29)
# ERROR:no viable alternative at input '-' (7.sysml line : 30 column : 30)
# ERROR:no viable alternative at input '}' (7.sysml line : 30 column : 55)
# ERROR:mismatched character '<EOF>' expecting ''' (7.sysml line : 30 column : 69)

# %%
# 8. SOTA: Semantic Clustering (The "Meaning" Map)
# This uses Machine Learning (TF-IDF + PCA) to cluster nodes based on their text content.
# It reveals "Hidden Connections" that might not be explicitly linked in the graph.

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans

# 1. Prepare Data (Use Node Labels/Content)
node_ids = list(G.nodes())
# If we have 'content' attribute, use it. Otherwise use 'label' or ID.
corpus = [str(G.nodes[n].get('label', n)) for n in node_ids]

# 2. Vectorize (Convert Text to Numbers)
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(corpus)

# 3. Dimensionality Reduction (Compress to 2D for plotting)
pca = PCA(n_components=2)
coords = pca.fit_transform(X.toarray())

# 4. Clustering (Find Topics)
# We'll guess k=5 clusters for now
kmeans = KMeans(n_clusters=5, random_state=42)
clusters = kmeans.fit_predict(X)

# 5. Visualize
plt.figure(figsize=(12, 8))
scatter = plt.scatter(coords[:, 0], coords[:, 1], c=clusters, cmap='viridis', alpha=0.6)

# Label some points
for i, txt in enumerate(node_ids):
    if i % 10 == 0: # Label every 10th node to avoid clutter
        plt.annotate(txt, (coords[i, 0], coords[i, 1]), fontsize=8, alpha=0.7)

plt.title("Semantic Space: Concept Clusters (TF-IDF + PCA)")
plt.xlabel("Semantic Dimension 1")
plt.ylabel("Semantic Dimension 2")
plt.colorbar(scatter, label="Topic Cluster")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ERROR:no viable alternative at input '8' (8.sysml line : 1 column : 1)
# ERROR:no viable alternative at input 'Clustering' (8.sysml line : 1 column : 12)
# ERROR:no viable alternative at input 'Clustering' (8.sysml line : 1 column : 21)
# ERROR:no viable alternative at input '"Meaning"' (8.sysml line : 1 column : 37)
# ERROR:no viable alternative at input ')' (8.sysml line : 1 column : 50)
# ERROR:no viable alternative at input 'Machine' (8.sysml line : 2 column : 13)
# ERROR:no viable alternative at input 'Learning' (8.sysml line : 2 column : 21)
# ERROR:no viable alternative at input '(' (8.sysml line : 2 column : 30)
# ERROR:no viable alternative at input '-' (8.sysml line : 2 column : 33)
# ERROR:no viable alternative at input '+' (8.sysml line : 2 column : 38)
# ERROR:no viable alternative at input ')' (8.sysml line : 2 column : 43)
# ERROR:no viable alternative at input 'nodes' (8.sysml line : 2 column : 56)
# ERROR:no viable alternative at input 'based' (8.sysml line : 2 column : 62)
# ERROR:no viable alternative at input 'on' (8.sysml line : 2 column : 68)
# ERROR:no viable alternative at input 'their' (8.sysml line : 2 column : 71)
# ERROR:no viable alternative at input 'text' (8.sysml line : 2 column : 77)
# ERROR:no viable alternative at input 'content' (8.sysml line : 2 column : 82)
# ERROR:no viable alternative at input '.' (8.sysml line : 2 column : 89)
# ERROR:no viable alternative at input '"Hidden Connections"' (8.sysml line : 3 column : 14)
# ERROR:no viable alternative at input 'might' (8.sysml line : 3 column : 40)
# ERROR:no viable alternative at input 'not' (8.sysml line : 3 column : 46)
# ERROR:no viable alternative at input 'explicitly' (8.sysml line : 3 column : 53)
# ERROR:no viable alternative at input 'linked' (8.sysml line : 3 column : 64)
# ERROR:no viable alternative at input 'in' (8.sysml line : 3 column : 71)
# ERROR:no viable alternative at input 'graph' (8.sysml line : 3 column : 78)
# ERROR:no viable alternative at input '.' (8.sysml line : 3 column : 83)
# ERROR:no viable alternative at input '.' (8.sysml line : 5 column : 13)
# ERROR:no viable alternative at input '.' (8.sysml line : 5 column : 32)
# ERROR:no viable alternative at input 'import' (8.sysml line : 5 column : 38)
# ERROR:no viable alternative at input 'from' (8.sysml line : 6 column : 1)
# ERROR:no viable alternative at input '.' (8.sysml line : 6 column : 13)
# ERROR:no viable alternative at input 'import' (8.sysml line : 6 column : 28)
# ERROR:no viable alternative at input 'from' (8.sysml line : 7 column : 1)
# ERROR:no viable alternative at input '.' (8.sysml line : 7 column : 13)
# ERROR:no viable alternative at input 'import' (8.sysml line : 7 column : 22)
# ERROR:no viable alternative at input '#' (8.sysml line : 9 column : 1)
# ERROR:no viable alternative at input 'Data' (8.sysml line : 9 column : 14)
# ERROR:no viable alternative at input '(' (8.sysml line : 9 column : 19)
# ERROR:no viable alternative at input 'Node' (8.sysml line : 9 column : 24)
# ERROR:no viable alternative at input 'Labels' (8.sysml line : 9 column : 29)
# ERROR:no viable alternative at input '/' (8.sysml line : 9 column : 35)
# ERROR:no viable alternative at input ')' (8.sysml line : 9 column : 43)
# ERROR:missing '(' at 'If' (8.sysml line : 11 column : 3)
# ERROR:no viable alternative at input 'have' (8.sysml line : 11 column : 9)
# ERROR:no viable alternative at input ''content'' (8.sysml line : 11 column : 14)
# ERROR:no viable alternative at input 'attribute' (8.sysml line : 11 column : 24)
# ERROR:no viable alternative at input 'it' (8.sysml line : 11 column : 35)
# ERROR:no viable alternative at input '.' (8.sysml line : 11 column : 41)
# ERROR:no viable alternative at input 'use' (8.sysml line : 11 column : 53)
# ERROR:no viable alternative at input 'or' (8.sysml line : 11 column : 65)
# ERROR:no viable alternative at input '.' (8.sysml line : 11 column : 70)
# ERROR:no viable alternative at input '[' (8.sysml line : 12 column : 10)
# ERROR:no viable alternative at input '(' (8.sysml line : 12 column : 14)
# ERROR:no viable alternative at input '.' (8.sysml line : 12 column : 16)
# ERROR:no viable alternative at input '.' (8.sysml line : 12 column : 22)
# ERROR:no viable alternative at input ']' (8.sysml line : 12 column : 24)
# ERROR:no viable alternative at input '(' (8.sysml line : 12 column : 29)
# ERROR:no viable alternative at input ',' (8.sysml line : 12 column : 37)
# ERROR:no viable alternative at input ')' (8.sysml line : 12 column : 40)
# ERROR:no viable alternative at input 'in' (8.sysml line : 12 column : 49)
# ERROR:no viable alternative at input ']' (8.sysml line : 12 column : 60)
# ERROR:no viable alternative at input '2' (8.sysml line : 14 column : 1)
# ERROR:no viable alternative at input '(' (8.sysml line : 14 column : 16)
# ERROR:no viable alternative at input 'Text' (8.sysml line : 14 column : 25)
# ERROR:no viable alternative at input 'to' (8.sysml line : 14 column : 30)
# ERROR:no viable alternative at input ')' (8.sysml line : 14 column : 40)
# ERROR:no viable alternative at input 'X' (8.sysml line : 16 column : 1)
# ERROR:missing '(' at '3' (8.sysml line : 18 column : 3)
# ERROR:no viable alternative at input 'Reduction' (8.sysml line : 18 column : 6)
# ERROR:no viable alternative at input '(' (8.sysml line : 18 column : 31)
# ERROR:no viable alternative at input 'to' (8.sysml line : 18 column : 41)
# ERROR:no viable alternative at input 'for' (8.sysml line : 18 column : 47)
# ERROR:no viable alternative at input ')' (8.sysml line : 18 column : 59)
# ERROR:no viable alternative at input 'coords' (8.sysml line : 20 column : 1)
# ERROR:missing '(' at '4' (8.sysml line : 22 column : 3)
# ERROR:no viable alternative at input '(' (8.sysml line : 22 column : 6)
# ERROR:no viable alternative at input 'Topics' (8.sysml line : 22 column : 23)
# ERROR:no viable alternative at input ')' (8.sysml line : 22 column : 29)
# ERROR:no viable alternative at input 'viridis' (8.sysml line : 29 column : 69)
# ERROR:mismatched character '<EOF>' expecting ''' (8.sysml line : 29 column : 76)

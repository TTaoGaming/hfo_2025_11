# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
from pathlib import Path

# Path to rescued data
data_dir = Path("../ingestion/staging_data")
files = list(data_dir.glob("*.jsonl"))

print(f"Found {len(files)} simulation logs.")
